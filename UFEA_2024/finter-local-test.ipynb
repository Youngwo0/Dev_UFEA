# %% [markdown]
# ### API Key Setting

# %%
import os
os.environ['FINTER_API_KEY'] = '03c2d62343b2038a2d45b60641ac6e5ed01a88f4'

# %%
from finter.framework_model import BaseAlpha
start, end = 20200101, 20220101

close_p = BaseAlpha.get_cm("content.fnguide.ftp.price_volume.price_close.1d").get_df(start, end)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/finter/utils/convert.py:23: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df.index = pd.to_datetime(df.index, unit='ms')

# %%
class Alpha(BaseAlpha):
    def get(self, start, end):
        self.data = self.get_cm(
            "content.fnguide.ftp.calendar.expiry_dates-future.1d"
        ).get_df(start, end)
        return self.data

# %%
Alpha().get(start, end).head(10)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/finter/utils/convert.py:23: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df.index = pd.to_datetime(df.index, unit='ms')
#                           406574    406576    406577  ...  430690  432543  433347
# 2019-12-31 23:59:00.608      NaN       NaN       NaN  ...     NaN     NaN     NaN
# 2020-01-02 00:00:48.128  0.01544  0.007785  0.000028  ...     NaN     NaN     NaN
# 2020-01-03 00:00:24.576  0.01544  0.007785  0.000028  ...     NaN     NaN     NaN
# 2020-01-04 00:00:01.024      NaN       NaN       NaN  ...     NaN     NaN     NaN
# 2020-01-04 23:59:37.472      NaN       NaN       NaN  ...     NaN     NaN     NaN
# ...

# %%
cm_name = 'content.fnguide.ftp.calendar.expiry_dates-future.1d'
print(BaseAlpha.get_cm(cm_name).get_df(20190103, 20200103))
# Out:
#                          KOSPI200지수선물_주가지수파생_코스피200  ...  유로스톡스50선물_유로스톡스50_유로스톡스50
# 2019-01-02 23:59:30.304                       False  ...                      False
# 2019-01-03 23:59:06.752                       False  ...                      False
# 2019-01-05 00:00:54.272                       False  ...                      False
# 2019-01-06 00:00:30.720                       False  ...                      False
# 2019-01-07 00:00:07.168                       False  ...                      False
# ...                                             ...  ...                        ...
# 2019-12-29 23:59:47.712                       False  ...                      False
# 2019-12-30 23:59:24.160                       False  ...                      False
# 2019-12-31 23:59:00.608                       False  ...                      False
# 2020-01-02 00:00:48.128                       False  ...                      False
# ...
